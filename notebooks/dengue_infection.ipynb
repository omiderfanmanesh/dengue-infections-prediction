# %%
import warnings
from configs import cfg
from data import load
from data.preprocessing import Encoders, Scalers
from eda.dengue_infection_analyser import DengueInfectionAnalyzer
from eda.dengue_infection_plot import DengueInfectionPlots
from engine.analyser import do_analysis


import numpy as np

np.seterr(all='warn')
warnings.simplefilter(action='ignore', category=FutureWarning)


from data.based.based_dataset import BasedDataset
from data.preprocessing import Encoders, Scalers
from eda.based.based_analyzer import BasedAnalyzer
from eda.based.based_plots import BasedPlot

# %%
def do_analysis(dataset: BasedDataset, plots: BasedPlot, analyzer: BasedAnalyzer, encoder: Encoders, scaler: Scalers):


    analyzer.persiann_precip_mm()
    # analyzer.avg_temp_c()
    # plots.corr(data=dataset.df)
    # plots.numerical_features_distribution()
    # plots.year()
    # plots.city()

# %%
den = load(cfg)
den.load_dataset()
den.drop_cols()
encoder = Encoders(cdg=cfg)
scaler = Scalers(cfg=cfg)
analyzer = DengueInfectionAnalyzer(dataset=den, cfg=cfg)
plots = DengueInfectionPlots(dataset=den, cfg=cfg)
do_analysis(dataset=den, analyzer=analyzer, plots=plots, encoder=encoder, scaler=scaler)

# %%
den.df.head()
# Out:
#    year  weekofyear week_start_date  PERSIANN_precip_mm  NCEP_air_temp_k  \
# 0  2000          26      2000-07-01               25.41       296.740000
# 1  2000          27      2000-07-08               60.61       296.634286
# 2  2000          28      2000-07-15               55.52       296.415714
# 3  2000          29      2000-07-22                5.60       295.357143
# 4  2000          30      2000-07-29               62.76       296.432857
#
#    NCEP_avg_temp_k  NCEP_dew_point_temp_k  NCEP_max_air_temp_k  \
# 0       298.450000             295.184286                307.3
# 1       298.428571             295.358571                306.6
# 2       297.392857             295.622857                304.5
# 3       296.228571             292.797143                303.6
# 4       297.635714             293.957143                307.0
#
#    NCEP_min_air_temp_k  NCEP_precip_kg_per_m2  NCEP_humidity_percent  \
# 0                293.1                  43.19              92.418571
# 1                291.1                  46.00              93.581429
# 2                292.6                  64.77              95.848571
# 3                288.6                  23.96              87.234286
# 4                291.5                  31.80              88.161429
#
#    NCEP_precip_mm  NCEP_humidity_g_per_kg  NCEP_diur_temp_rng_k  avg_temp_c  \
# 0           25.41               16.651429              8.928571   26.400000
# 1           60.61               16.862857             10.314286   26.900000
# 2           55.52               17.120000              7.385714   26.800000
# 3            5.60               14.431429              9.114286   25.766667
# 4           62.76               15.444286              9.500000   26.600000
#
#    diur_temp_rng_c  max_temp_c  min_temp_c  precip_mm  total_cases city  \
# 0        10.775000        32.5        20.7        3.0            0   iq
# 1        11.566667        34.0        20.8       55.6            0   iq
# 2        11.466667        33.0        20.7       38.1            0   iq
# 3        10.533333        31.5        14.7       30.0            0   iq
# 4        11.480000        33.3        19.1        4.0            0   iq
#
#    month  PERSIANN_precip_mm_no_nans  NCEP_avg_temp_c  \
# 0      7                       25.41        25.300000
# 1      7                       60.61        25.278571
# 2      7                       55.52        24.242857
# 3      7                        5.60        23.078571
# 4      7                       62.76        24.485714
#
#    NCEP_avg_temp_c_no_nans  NCEP_diur_temp_rng_c  \
# 0                25.300000           -264.221429
# 1                25.278571           -262.835714
# 2                24.242857           -265.764286
# 3                23.078571           -264.035714
# 4                24.485714           -263.650000
#
#    NCEP_diur_temp_rng_c_no_nans  NCEP_max_air_temp_c  \
# 0                   -264.221429                34.15
# 1                   -262.835714                33.45
# 2                   -265.764286                31.35
# 3                   -264.035714                30.45
# 4                   -263.650000                33.85
#
#    NCEP_max_air_temp_c_no_nans  NCEP_min_air_temp_c  \
# 0                        34.15                19.95
# 1                        33.45                17.95
# 2                        31.35                19.45
# 3                        30.45                15.45
# 4                        33.85                18.35
#
#    NCEP_min_air_temp_c_no_nans  NCEP_air_temp_c  NCEP_air_temp_c_no_nans  \
# 0                        19.95        23.590000                23.590000
# 1                        17.95        23.484286                23.484286
# 2                        19.45        23.265714                23.265714
# 3                        15.45        22.207143                22.207143
# 4                        18.35        23.282857                23.282857
#
#    NCEP_dew_point_temp_c  NCEP_dew_point_temp_c_no_nans  avg_temp_c_no_nans  \
# 0              22.034286                      22.034286           26.400000
# 1              22.208571                      22.208571           26.900000
# 2              22.472857                      22.472857           26.800000
# 3              19.647143                      19.647143           25.766667
# 4              20.807143                      20.807143           26.600000
#
#    diur_temp_rng_c_no_nans  max_temp_c_no_nans  min_temp_c_no_nans  \
# 0                10.775000                32.5                20.7
# 1                11.566667                34.0                20.8
# 2                11.466667                33.0                20.7
# 3                10.533333                31.5                14.7
# 4                11.480000                33.3                19.1
#
#    precip_mm_no_nans
# 0                3.0
# 1               55.6
# 2               38.1
# 3               30.0
# 4                4.0

# %%
den.df.columns
# Out:
# Index(['year', 'weekofyear', 'week_start_date', 'PERSIANN_precip_mm',
#        'NCEP_air_temp_k', 'NCEP_avg_temp_k', 'NCEP_dew_point_temp_k',
#        'NCEP_max_air_temp_k', 'NCEP_min_air_temp_k', 'NCEP_precip_kg_per_m2',
#        'NCEP_humidity_percent', 'NCEP_precip_mm', 'NCEP_humidity_g_per_kg',
#        'NCEP_diur_temp_rng_k', 'avg_temp_c', 'diur_temp_rng_c', 'max_temp_c',
#        'min_temp_c', 'precip_mm', 'total_cases', 'city', 'month',
#        'PERSIANN_precip_mm_no_nans', 'NCEP_avg_temp_c',
#        'NCEP_avg_temp_c_no_nans', 'NCEP_diur_temp_rng_c',
#        'NCEP_diur_temp_rng_c_no_nans', 'NCEP_max_air_temp_c',
#        'NCEP_max_air_temp_c_no_nans', 'NCEP_min_air_temp_c',
#        'NCEP_min_air_temp_c_no_nans', 'NCEP_air_temp_c',
#        'NCEP_air_temp_c_no_nans', 'NCEP_dew_point_temp_c',
#        'NCEP_dew_point_temp_c_no_nans', 'avg_temp_c_no_nans',
#        'diur_temp_rng_c_no_nans', 'max_temp_c_no_nans', 'min_temp_c_no_nans',
#        'precip_mm_no_nans'],
#       dtype='object')

# %%
analyzer.description()
# Out:
# --------------- dataframe info ----------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   year                           1205 non-null   int64
#  1   weekofyear                     1205 non-null   int64
#  2   week_start_date                1205 non-null   datetime64[ns]
#  3   PERSIANN_precip_mm             1194 non-null   float64
#  4   NCEP_air_temp_k                1197 non-null   float64
#  5   NCEP_avg_temp_k                1197 non-null   float64
#  6   NCEP_dew_point_temp_k          1197 non-null   float64
#  7   NCEP_max_air_temp_k            1197 non-null   float64
#  8   NCEP_min_air_temp_k            1197 non-null   float64
#  9   NCEP_precip_kg_per_m2          1197 non-null   float64
#  10  NCEP_humidity_percent          1197 non-null   float64
#  11  NCEP_precip_mm                 1194 non-null   float64
#  12  NCEP_humidity_g_per_kg         1197 non-null   float64
#  13  NCEP_diur_temp_rng_k           1197 non-null   float64
#  14  avg_temp_c                     1173 non-null   float64
#  15  diur_temp_rng_c                1173 non-null   float64
#  16  max_temp_c                     1193 non-null   float64
#  17  min_temp_c                     1193 non-null   float64
#  18  precip_mm                      1190 non-null   float64
#  19  total_cases                    1205 non-null   int64
#  20  city                           1205 non-null   object
#  21  month                          1205 non-null   int64
#  22  PERSIANN_precip_mm_no_nans     1205 non-null   float64
#  23  NCEP_avg_temp_c                1197 non-null   float64
#  24  NCEP_avg_temp_c_no_nans        1205 non-null   float64
#  25  NCEP_diur_temp_rng_c           1197 non-null   float64
#  26  NCEP_diur_temp_rng_c_no_nans   1205 non-null   float64
#  27  NCEP_max_air_temp_c            1197 non-null   float64
#  28  NCEP_max_air_temp_c_no_nans    1205 non-null   float64
#  29  NCEP_min_air_temp_c            1197 non-null   float64
#  30  NCEP_min_air_temp_c_no_nans    1205 non-null   float64
#  31  NCEP_air_temp_c                1197 non-null   float64
#  32  NCEP_air_temp_c_no_nans        1205 non-null   float64
#  33  NCEP_dew_point_temp_c          1197 non-null   float64
#  34  NCEP_dew_point_temp_c_no_nans  1205 non-null   float64
#  35  avg_temp_c_no_nans             1201 non-null   float64
#  36  diur_temp_rng_c_no_nans        1201 non-null   float64
#  37  max_temp_c_no_nans             1205 non-null   float64
#  38  min_temp_c_no_nans             1205 non-null   float64
#  39  precip_mm_no_nans              1205 non-null   float64
# dtypes: datetime64[ns](1), float64(34), int64(4), object(1)
# memory usage: 376.7+ KB
# None
#
#
# ---------- dataframe description --------------
#                                 count         mean        std          min  \
# year                           1205.0  1999.623237   4.847247  1990.000000
# weekofyear                     1205.0    27.009129  14.944162     1.000000
# PERSIANN_precip_mm             1194.0    44.906533  44.607227     0.000000
# NCEP_air_temp_k                1197.0   298.715226   1.339849   294.635714
# NCEP_avg_temp_k                1197.0   299.203354   1.245218   294.892857
# NCEP_dew_point_temp_k          1197.0   295.191122   1.542649   289.642857
# NCEP_max_air_temp_k            1197.0   303.252799   3.241444   297.800000
# NCEP_min_air_temp_k            1197.0   295.797327   2.566590   286.900000
# NCEP_precip_kg_per_m2          1197.0    38.365823  42.547069     0.000000
# NCEP_humidity_percent          1197.0    81.770154   6.760307    57.787143
# NCEP_precip_mm                 1194.0    44.906533  44.607227     0.000000
# NCEP_humidity_g_per_kg         1197.0    16.684940   1.544943    11.715714
# NCEP_diur_temp_rng_k           1197.0     4.752142   3.606676     1.357143
# avg_temp_c                     1173.0    27.178070   1.280489    21.400000
# diur_temp_rng_c                1173.0     7.945935   2.032523     4.528571
# max_temp_c                     1193.0    32.375524   1.870180    26.700000
# min_temp_c                     1193.0    22.150042   1.606453    14.700000
# precip_mm                      1190.0    40.189076  49.187120     0.000000
# total_cases                    1205.0    26.517842  46.582143     0.000000
# month                          1205.0     6.539419   3.438759     1.000000
# PERSIANN_precip_mm_no_nans     1205.0    44.695961  44.503877     0.000000
# NCEP_avg_temp_c                1197.0    26.053354   1.245218    21.742857
# NCEP_avg_temp_c_no_nans        1205.0    26.048328   1.245968    21.742857
# NCEP_diur_temp_rng_c           1197.0  -268.397858   3.606676  -271.792857
# NCEP_diur_temp_rng_c_no_nans   1205.0  -268.402833   3.604599  -271.792857
# NCEP_max_air_temp_c            1197.0    30.102799   3.241444    24.650000
# NCEP_max_air_temp_c_no_nans    1205.0    30.092614   3.244950    24.650000
# NCEP_min_air_temp_c            1197.0    22.647327   2.566590    13.750000
# NCEP_min_air_temp_c_no_nans    1205.0    22.645975   2.559540    13.750000
# NCEP_air_temp_c                1197.0    25.565226   1.339849    21.485714
# NCEP_air_temp_c_no_nans        1205.0    25.560534   1.337644    21.485714
# NCEP_dew_point_temp_c          1197.0    22.041122   1.542649    16.492857
# NCEP_dew_point_temp_c_no_nans  1205.0    22.035520   1.542097    16.492857
# avg_temp_c_no_nans             1201.0    27.173027   1.278837    21.400000
# diur_temp_rng_c_no_nans        1201.0     7.979100   2.040526     4.528571
# max_temp_c_no_nans             1205.0    32.369004   1.879931    26.700000
# min_temp_c_no_nans             1205.0    22.142254   1.603485    14.700000
# precip_mm_no_nans              1205.0    40.283997  49.090431     0.000000
#
#                                        25%          50%          75%  \
# year                           1996.000000  2001.000000  2004.000000
# weekofyear                       14.000000    27.000000    40.000000
# PERSIANN_precip_mm                8.540000    36.610000    68.705000
# NCEP_air_temp_k                 297.675714   298.682857   299.850000
# NCEP_avg_temp_k                 298.257143   299.292857   300.150000
# NCEP_dew_point_temp_k           294.037143   295.568571   296.424286
# NCEP_max_air_temp_k             300.900000   302.300000   305.100000
# NCEP_min_air_temp_k             294.000000   296.300000   298.000000
# NCEP_precip_kg_per_m2            12.800000    26.100000    49.200000
# NCEP_humidity_percent            77.357143    80.255714    84.467143
# NCEP_precip_mm                    8.540000    36.610000    68.705000
# NCEP_humidity_g_per_kg           15.488571    17.010000    17.940000
# NCEP_diur_temp_rng_k              2.285714     2.728571     7.371429
# avg_temp_c                       26.300000    27.400000    28.157143
# diur_temp_rng_c                   6.528571     7.242857     9.300000
# max_temp_c                       31.100000    32.800000    33.700000
# min_temp_c                       21.100000    22.200000    23.300000
# precip_mm                         8.700000    24.100000    55.100000
# total_cases                       5.000000    13.000000    30.000000
# month                             4.000000     7.000000    10.000000
# PERSIANN_precip_mm_no_nans        8.490000    36.200000    68.220000
# NCEP_avg_temp_c                  25.107143    26.142857    27.000000
# NCEP_avg_temp_c_no_nans          25.092857    26.135714    27.000000
# NCEP_diur_temp_rng_c           -270.864286  -270.421429  -265.778571
# NCEP_diur_temp_rng_c_no_nans   -270.878571  -270.435714  -265.778571
# NCEP_max_air_temp_c              27.750000    29.150000    31.950000
# NCEP_max_air_temp_c_no_nans      27.750000    29.150000    31.950000
# NCEP_min_air_temp_c              20.850000    23.150000    24.850000
# NCEP_min_air_temp_c_no_nans      20.850000    23.150000    24.850000
# NCEP_air_temp_c                  24.525714    25.532857    26.700000
# NCEP_air_temp_c_no_nans          24.524286    25.531429    26.698571
# NCEP_dew_point_temp_c            20.887143    22.418571    23.274286
# NCEP_dew_point_temp_c_no_nans    20.882857    22.412857    23.270000
# avg_temp_c_no_nans               26.300000    27.400000    28.150000
# diur_temp_rng_c_no_nans           6.528571     7.257143     9.433333
# max_temp_c_no_nans               31.100000    32.800000    33.800000
# min_temp_c_no_nans               21.100000    22.200000    23.300000
# precip_mm_no_nans                 8.700000    24.100000    55.600000
#
#                                        max
# year                           2007.000000
# weekofyear                       53.000000
# PERSIANN_precip_mm              390.600000
# NCEP_air_temp_k                 302.200000
# NCEP_avg_temp_k                 302.928571
# NCEP_dew_point_temp_k           297.852857
# NCEP_max_air_temp_k             314.000000
# NCEP_min_air_temp_k             299.900000
# NCEP_precip_kg_per_m2           570.500000
# NCEP_humidity_percent            98.457143
# NCEP_precip_mm                  390.600000
# NCEP_humidity_g_per_kg           19.731429
# NCEP_diur_temp_rng_k             16.028571
# avg_temp_c                       30.800000
# diur_temp_rng_c                  15.800000
# max_temp_c                       42.200000
# min_temp_c                       25.600000
# precip_mm                       543.300000
# total_cases                     461.000000
# month                            12.000000
# PERSIANN_precip_mm_no_nans      390.600000
# NCEP_avg_temp_c                  29.778571
# NCEP_avg_temp_c_no_nans          29.778571
# NCEP_diur_temp_rng_c           -257.121429
# NCEP_diur_temp_rng_c_no_nans   -257.121429
# NCEP_max_air_temp_c              40.850000
# NCEP_max_air_temp_c_no_nans      40.850000
# NCEP_min_air_temp_c              26.750000
# NCEP_min_air_temp_c_no_nans      26.750000
# NCEP_air_temp_c                  29.050000
# NCEP_air_temp_c_no_nans          29.050000
# NCEP_dew_point_temp_c            24.702857
# NCEP_dew_point_temp_c_no_nans    24.702857
# avg_temp_c_no_nans               30.800000
# diur_temp_rng_c_no_nans          15.800000
# max_temp_c_no_nans               42.200000
# min_temp_c_no_nans               25.600000
# precip_mm_no_nans               543.300000
#
#
# --------------- dataframe columns -----------------
# Index(['year', 'weekofyear', 'week_start_date', 'PERSIANN_precip_mm',
#        'NCEP_air_temp_k', 'NCEP_avg_temp_k', 'NCEP_dew_point_temp_k',
#        'NCEP_max_air_temp_k', 'NCEP_min_air_temp_k', 'NCEP_precip_kg_per_m2',
#        'NCEP_humidity_percent', 'NCEP_precip_mm', 'NCEP_humidity_g_per_kg',
#        'NCEP_diur_temp_rng_k', 'avg_temp_c', 'diur_temp_rng_c', 'max_temp_c',
#        'min_temp_c', 'precip_mm', 'total_cases', 'city', 'month',
#        'PERSIANN_precip_mm_no_nans', 'NCEP_avg_temp_c',
#        'NCEP_avg_temp_c_no_nans', 'NCEP_diur_temp_rng_c',
#        'NCEP_diur_temp_rng_c_no_nans', 'NCEP_max_air_temp_c',
#        'NCEP_max_air_temp_c_no_nans', 'NCEP_min_air_temp_c',
#        'NCEP_min_air_temp_c_no_nans', 'NCEP_air_temp_c',
#        'NCEP_air_temp_c_no_nans', 'NCEP_dew_point_temp_c',
#        'NCEP_dew_point_temp_c_no_nans', 'avg_temp_c_no_nans',
#        'diur_temp_rng_c_no_nans', 'max_temp_c_no_nans', 'min_temp_c_no_nans',
#        'precip_mm_no_nans'],
#       dtype='object')
#
#
# --------------- nan Values -----------------
#                         Total   Percent
# avg_temp_c                 32  0.026556
# diur_temp_rng_c            32  0.026556
# precip_mm                  15  0.012448
# max_temp_c                 12  0.009959
# min_temp_c                 12  0.009959
# PERSIANN_precip_mm         11  0.009129
# NCEP_precip_mm             11  0.009129
# NCEP_dew_point_temp_k       8  0.006639
# NCEP_diur_temp_rng_c        8  0.006639
# NCEP_humidity_percent       8  0.006639
# NCEP_precip_kg_per_m2       8  0.006639
# NCEP_min_air_temp_k         8  0.006639
# NCEP_avg_temp_c             8  0.006639
# NCEP_max_air_temp_k         8  0.006639
# NCEP_diur_temp_rng_k        8  0.006639
# NCEP_humidity_g_per_kg      8  0.006639
# NCEP_max_air_temp_c         8  0.006639
# NCEP_avg_temp_k             8  0.006639
# NCEP_min_air_temp_c         8  0.006639
# NCEP_air_temp_k             8  0.006639
#
#
# --------------- duplicates -----------------
# Total number of duplicates:  0
#
#
# ------ Numerical/Categorical Features ------
# Numerical Features: ['year', 'weekofyear', 'week_start_date', 'PERSIANN_precip_mm', 'NCEP_air_temp_k', 'NCEP_avg_temp_k', 'NCEP_dew_point_temp_k', 'NCEP_max_air_temp_k', 'NCEP_min_air_temp_k', 'NCEP_precip_kg_per_m2', 'NCEP_humidity_percent', 'NCEP_precip_mm', 'NCEP_humidity_g_per_kg', 'NCEP_diur_temp_rng_k', 'avg_temp_c', 'diur_temp_rng_c', 'max_temp_c', 'min_temp_c', 'precip_mm', 'total_cases', 'month', 'PERSIANN_precip_mm_no_nans', 'NCEP_avg_temp_c', 'NCEP_avg_temp_c_no_nans', 'NCEP_diur_temp_rng_c', 'NCEP_diur_temp_rng_c_no_nans', 'NCEP_max_air_temp_c', 'NCEP_max_air_temp_c_no_nans', 'NCEP_min_air_temp_c', 'NCEP_min_air_temp_c_no_nans', 'NCEP_air_temp_c', 'NCEP_air_temp_c_no_nans', 'NCEP_dew_point_temp_c', 'NCEP_dew_point_temp_c_no_nans', 'avg_temp_c_no_nans', 'diur_temp_rng_c_no_nans', 'max_temp_c_no_nans', 'min_temp_c_no_nans', 'precip_mm_no_nans']
# number of Numerical Features: 39
# Categorical Features: ['city']
# number of Categorical Features: 1
#
#
# --------------- skew & kurt -----------------
# calculate skewness and kurtosis of numerical features
#                                    skew  skew log  skew sqrt  skew box cox   \
# total_cases                    5.055286 -0.124762   2.063836      -0.001903
# NCEP_precip_kg_per_m2          3.823533 -0.427445   1.209573      34.572489
# precip_mm                      3.007655 -0.474739   1.034915      34.455878
# precip_mm_no_nans              2.995978 -0.481559   1.029299      -0.028625
# PERSIANN_precip_mm_no_nans     1.897981 -0.881761   0.219240      -0.200861
# PERSIANN_precip_mm             1.891893 -0.887199   0.214744      24.285153
# NCEP_precip_mm                 1.891893 -0.887199   0.214744      24.285153
# NCEP_diur_temp_rng_c_no_nans   1.195133  0.705246   0.947631       0.270207
# NCEP_diur_temp_rng_k           1.194886  0.745419   0.964174       6.754295
# NCEP_diur_temp_rng_c           1.194886  0.703119   0.946641       6.977603
# NCEP_max_air_temp_k            0.971255  0.953335   0.962287       1.107527
# NCEP_max_air_temp_c            0.971255  0.799626   0.885196       2.499363
# NCEP_max_air_temp_c_no_nans    0.968709  0.797518   0.882847       0.000000
# diur_temp_rng_c                0.947567  0.525725   0.740950       8.621379
# diur_temp_rng_c_no_nans        0.903798  0.490940   0.701363       8.623948
# NCEP_humidity_percent          0.627651  0.401567   0.519328       1.655750
# month                         -0.046910 -1.004475  -0.475108      -0.234354
# weekofyear                    -0.048019 -1.447169  -0.570612      -0.273303
# NCEP_air_temp_c_no_nans       -0.138002 -0.244248  -0.190494      -0.027143
# NCEP_air_temp_k               -0.145589 -0.154371  -0.149976      -0.080827
# NCEP_air_temp_c               -0.145589 -0.251750  -0.198040       0.547666
# NCEP_avg_temp_c_no_nans       -0.210829 -0.319495  -0.264821      -0.024451
# NCEP_avg_temp_c               -0.217364 -0.326813  -0.271742       0.590867
# NCEP_avg_temp_k               -0.217364 -0.226702  -0.222031      -0.147892
# max_temp_c                    -0.268849 -0.460923  -0.367034       3.442346
# max_temp_c_no_nans            -0.273462 -0.462716  -0.370211       0.028265
# min_temp_c_no_nans            -0.387462 -0.650555  -0.512809      -0.018712
# min_temp_c                    -0.397961 -0.661649  -0.523604       0.839397
# year                          -0.407556 -0.410621  -0.409089            NaN
# NCEP_humidity_g_per_kg        -0.557903 -0.741193  -0.646831       0.466929
# avg_temp_c_no_nans            -0.570402 -0.688784  -0.628558       0.208286
# avg_temp_c                    -0.571746 -0.691113  -0.630365       0.209989
# NCEP_dew_point_temp_c_no_nans -0.725117 -0.883503  -0.801890      -0.152335
# NCEP_dew_point_temp_c         -0.735157 -0.893933  -0.812133       0.089362
# NCEP_dew_point_temp_k         -0.735157 -0.745846  -0.740492      -0.657653
# NCEP_min_air_temp_k           -0.780068 -0.797415  -0.788715      -0.656855
# NCEP_min_air_temp_c           -0.780068 -1.054222  -0.909434       0.330540
# NCEP_min_air_temp_c_no_nans   -0.780311 -1.055923  -0.910383      -0.194476
#
#                                     kurt  kurt log  kurt sqrt  kurt box cox
# total_cases                    32.700020 -0.154602   6.760028     -0.104474
# NCEP_precip_kg_per_m2          28.167380  0.259260   2.961162   1195.821122
# precip_mm                      15.289120 -0.195408   1.469737   1188.110681
# precip_mm_no_nans              15.211111 -0.178764   1.456098     -0.387854
# PERSIANN_precip_mm_no_nans      7.625193 -0.524708  -0.315754     -0.775523
# PERSIANN_precip_mm              7.584942 -0.513791  -0.317116    590.636481
# NCEP_precip_mm                  7.584942 -0.513791  -0.317116    590.636481
# NCEP_diur_temp_rng_c_no_nans    0.036326 -1.041377  -0.628937     -1.194727
# NCEP_diur_temp_rng_k            0.036503 -1.000733  -0.594819     62.572689
# NCEP_diur_temp_rng_c            0.036503 -1.041863  -0.628987     66.918404
# NCEP_max_air_temp_k             0.071798  0.032030   0.051766      0.408510
# NCEP_max_air_temp_c             0.071798 -0.257328  -0.104481      7.351120
# NCEP_max_air_temp_c_no_nans     0.063119 -0.265769  -0.113025      0.000000
# diur_temp_rng_c                 0.080061 -0.491042  -0.281449    121.407491
# diur_temp_rng_c_no_nans        -0.027684 -0.560053  -0.368223    122.377357
# NCEP_humidity_percent           0.063876  0.184109   0.097240      1.694095
# month                          -1.194098  0.043730  -0.866807     -1.099781
# weekofyear                     -1.182963  1.859135  -0.637544     -1.035369
# NCEP_air_temp_c_no_nans        -0.674861 -0.561086  -0.623549     -0.751586
# NCEP_air_temp_k                -0.675831 -0.668172  -0.672038     -0.724070
# NCEP_air_temp_c                -0.675831 -0.560842  -0.623904     -0.442341
# NCEP_avg_temp_c_no_nans        -0.471395 -0.372603  -0.428370     -0.528263
# NCEP_avg_temp_c                -0.457140 -0.355726  -0.412862      0.312065
# NCEP_avg_temp_k                -0.457140 -0.450886  -0.454058     -0.492590
# max_temp_c                      0.432328  0.315176   0.346520     43.365666
# max_temp_c_no_nans              0.387496  0.274079   0.304261      1.023884
# min_temp_c_no_nans              0.255739  1.037327   0.590662     -0.349126
# min_temp_c                      0.265219  1.052246   0.602808      0.248230
# year                           -0.991704 -0.989421  -0.990566           NaN
# NCEP_humidity_g_per_kg         -0.502737 -0.094747  -0.319910     -0.580776
# avg_temp_c_no_nans             -0.091932  0.188987   0.036001     -0.208034
# avg_temp_c                     -0.080549  0.205774   0.049841     -0.206955
# NCEP_dew_point_temp_c_no_nans  -0.121425  0.339036   0.090521     -1.015387
# NCEP_dew_point_temp_c          -0.103392  0.360161   0.110084     -1.027983
# NCEP_dew_point_temp_k          -0.103392 -0.075682  -0.089613     -0.292149
# NCEP_min_air_temp_k            -0.072522 -0.025559  -0.049236     -0.377575
# NCEP_min_air_temp_c            -0.072522  0.814282   0.314484     -1.070341
# NCEP_min_air_temp_c_no_nans    -0.060913  0.831298   0.328415     -1.094387
#
#
# ----------------- quantiles -----------------
#                                       0.10         0.25         0.50  \
# year                           1992.000000  1996.000000  2001.000000
# weekofyear                        6.000000    14.000000    27.000000
# PERSIANN_precip_mm                0.000000     8.540000    36.610000
# NCEP_air_temp_k                 297.024571   297.675714   298.682857
# NCEP_avg_temp_k                 297.585714   298.257143   299.292857
# NCEP_dew_point_temp_k           293.009429   294.037143   295.568571
# NCEP_max_air_temp_k             299.900000   300.900000   302.300000
# NCEP_min_air_temp_k             292.000000   294.000000   296.300000
# NCEP_precip_kg_per_m2             5.452000    12.800000    26.100000
# NCEP_humidity_percent            74.791143    77.357143    80.255714
# NCEP_precip_mm                    0.000000     8.540000    36.610000
# NCEP_humidity_g_per_kg           14.482857    15.488571    17.010000
# NCEP_diur_temp_rng_k              1.985714     2.285714     2.728571
# avg_temp_c                       25.285714    26.300000    27.400000
# diur_temp_rng_c                   5.957143     6.528571     7.242857
# max_temp_c                       29.400000    31.100000    32.800000
# min_temp_c                       20.000000    21.100000    22.200000
# precip_mm                         2.890000     8.700000    24.100000
# total_cases                       1.000000     5.000000    13.000000
# month                             2.000000     4.000000     7.000000
# PERSIANN_precip_mm_no_nans        0.000000     8.490000    36.200000
# NCEP_avg_temp_c                  24.435714    25.107143    26.142857
# NCEP_avg_temp_c_no_nans          24.427143    25.092857    26.135714
# NCEP_diur_temp_rng_c           -271.164286  -270.864286  -270.421429
# NCEP_diur_temp_rng_c_no_nans   -271.164286  -270.878571  -270.435714
# NCEP_max_air_temp_c              26.750000    27.750000    29.150000
# NCEP_max_air_temp_c_no_nans      26.750000    27.750000    29.150000
# NCEP_min_air_temp_c              18.850000    20.850000    23.150000
# NCEP_min_air_temp_c_no_nans      18.850000    20.850000    23.150000
# NCEP_air_temp_c                  23.874571    24.525714    25.532857
# NCEP_air_temp_c_no_nans          23.881429    24.524286    25.531429
# NCEP_dew_point_temp_c            19.859429    20.887143    22.418571
# NCEP_dew_point_temp_c_no_nans    19.868000    20.882857    22.412857
# avg_temp_c_no_nans               25.257143    26.300000    27.400000
# diur_temp_rng_c_no_nans           5.957143     6.528571     7.257143
# max_temp_c_no_nans               29.400000    31.100000    32.800000
# min_temp_c_no_nans               20.000000    21.100000    22.200000
# precip_mm_no_nans                 2.900000     8.700000    24.100000
#
#                                       0.75
# year                           2004.000000
# weekofyear                       40.000000
# PERSIANN_precip_mm               68.705000
# NCEP_air_temp_k                 299.850000
# NCEP_avg_temp_k                 300.150000
# NCEP_dew_point_temp_k           296.424286
# NCEP_max_air_temp_k             305.100000
# NCEP_min_air_temp_k             298.000000
# NCEP_precip_kg_per_m2            49.200000
# NCEP_humidity_percent            84.467143
# NCEP_precip_mm                   68.705000
# NCEP_humidity_g_per_kg           17.940000
# NCEP_diur_temp_rng_k              7.371429
# avg_temp_c                       28.157143
# diur_temp_rng_c                   9.300000
# max_temp_c                       33.700000
# min_temp_c                       23.300000
# precip_mm                        55.100000
# total_cases                      30.000000
# month                            10.000000
# PERSIANN_precip_mm_no_nans       68.220000
# NCEP_avg_temp_c                  27.000000
# NCEP_avg_temp_c_no_nans          27.000000
# NCEP_diur_temp_rng_c           -265.778571
# NCEP_diur_temp_rng_c_no_nans   -265.778571
# NCEP_max_air_temp_c              31.950000
# NCEP_max_air_temp_c_no_nans      31.950000
# NCEP_min_air_temp_c              24.850000
# NCEP_min_air_temp_c_no_nans      24.850000
# NCEP_air_temp_c                  26.700000
# NCEP_air_temp_c_no_nans          26.698571
# NCEP_dew_point_temp_c            23.274286
# NCEP_dew_point_temp_c_no_nans    23.270000
# avg_temp_c_no_nans               28.150000
# diur_temp_rng_c_no_nans           9.433333
# max_temp_c_no_nans               33.800000
# min_temp_c_no_nans               23.300000
# precip_mm_no_nans                55.600000
#
#
# ----------------- is target balanced? -----------------
#      value  counts
# 0        0      88
# 1        6      64
# 2        2      54
# 3        7      52
# 4        5      51
# 5        3      49
# 6        4      44
# 7        1      40
# 8        8      37
# 9       11      33
# 10      10      30
# 11       9      29
# 12      17      29
# 13      13      27
# 14      14      26
# 15      18      25
# 16      16      24
# 17      12      21
# 18      21      19
# 19      23      18
# 20      26      18
# 21      30      17
# 22      20      17
# 23      25      16
# 24      28      16
# 25      22      16
# 26      31      15
# 27      15      13
# 28      19      12
# 29      29      12
# 30      37      12
# 31      33      12
# 32      27      11
# 33      24      10
# 34      34      10
# 35      38       9
# 36      56       9
# 37      35       8
# 38      55       7
# 39      40       7
# 40      36       6
# 41      32       6
# 42      47       6
# 43      42       5
# 44      39       5
# 45      43       5
# 46      53       5
# 47      46       5
# 48      64       4
# 49      75       4
# 50      65       4
# 51      70       4
# 52      68       4
# 53      67       4
# 54      61       4
# 55      60       4
# 56      59       4
# 57      71       4
# 58      49       4
# 59      48       4
# 60      44       4
# 61      73       3
# 62      72       3
# 63     140       3
# 64      41       3
# 65     127       3
# 66      89       3
# 67      50       3
# 68      52       3
# 69     112       3
# 70      62       3
# 71     129       2
# 72      57       2
# 73      82       2
# 74      54       2
# 75      51       2
# 76      83       2
# 77      76       2
# 78      80       2
# 79      45       2
# 80      66       2
# 81     102       2
# 82     116       2
# 83      84       2
# 84      85       2
# 85      91       1
# 86     149       1
# 87      74       1
# 88     426       1
# 89      63       1
# 90      77       1
# 91      78       1
# 92      81       1
# 93      90       1
# 94     142       1
# 95     141       1
# 96      92       1
# 97      99       1
# 98     104       1
# 99     108       1
# 100    115       1
# 101    126       1
# 102    128       1
# 103    131       1
# 104    137       1
# 105    119       1
# 106    150       1
# 107    288       1
# 108    169       1
# 109    410       1
# 110    191       1
# 111    256       1
# 112    220       1
# 113    181       1
# 114    221       1
# 115    204       1
# 116    179       1
# 117    202       1
# 118    333       1
# 119    263       1
# 120    272       1
# 121    302       1
# 122    329       1
# 123    154       1
# 124    353       1
# 125    359       1
# 126    364       1
# 127    381       1
# 128    395       1
# 129    461       1
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/scipy/stats/morestats.py:906: RuntimeWarning: overflow encountered in power
#   variance = np.var(data**lmb / lmb, axis=0)
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/numpy/core/_methods.py:202: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/pandas/core/nanops.py:1028: RuntimeWarning: overflow encountered in multiply
#   adjusted3 = adjusted2 * adjusted
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/pandas/core/nanops.py:1040: RuntimeWarning: overflow encountered in power
#   result = (count * (count - 1) ** 0.5 / (count - 2)) * (m3 / m2 ** 1.5)
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/pandas/core/nanops.py:1112: RuntimeWarning: overflow encountered in square
#   adjusted4 = adjusted2 ** 2
# /home/omid/anaconda3/envs/ml/lib/python3.8/site-packages/pandas/core/nanops.py:1119: RuntimeWarning: overflow encountered in square
#   denom = (count - 2) * (count - 3) * m2 ** 2

# %%
den.df[den.df['PERSIANN_precip_mm'].isna()].head()
# Out:
#      year  weekofyear week_start_date  PERSIANN_precip_mm  NCEP_air_temp_k  \
# 182  2004           1      2004-01-01                 NaN              NaN
# 234  2005          53      2005-01-01                 NaN              NaN
# 477  1992           1      1992-01-01                 NaN              NaN
# 483  1992           7      1992-02-12                 NaN       297.798571
# 484  1992           8      1992-02-19                 NaN       297.898571
#
#      NCEP_avg_temp_k  NCEP_dew_point_temp_k  NCEP_max_air_temp_k  \
# 182              NaN                    NaN                  NaN
# 234              NaN                    NaN                  NaN
# 477              NaN                    NaN                  NaN
# 483       298.057143             294.650000                300.2
# 484       298.107143             293.628571                300.1
#
#      NCEP_min_air_temp_k  NCEP_precip_kg_per_m2  NCEP_humidity_percent  \
# 182                  NaN                    NaN                    NaN
# 234                  NaN                    NaN                    NaN
# 477                  NaN                    NaN                    NaN
# 483                295.3                   20.1              82.875714
# 484                296.3                    4.4              77.295714
#
#      NCEP_precip_mm  NCEP_humidity_g_per_kg  NCEP_diur_temp_rng_k  avg_temp_c  \
# 182             NaN                     NaN                   NaN         NaN
# 234             NaN                     NaN                   NaN         NaN
# 477             NaN                     NaN                   NaN         NaN
# 483             NaN               16.060000              2.200000   26.028571
# 484             NaN               15.012857              2.585714   25.757143
#
#      diur_temp_rng_c  max_temp_c  min_temp_c  precip_mm  total_cases city  \
# 182              NaN         NaN         NaN        NaN            4   iq
# 234              NaN         NaN         NaN        NaN            9   iq
# 477              NaN         NaN         NaN        NaN           81   sj
# 483         6.571429        32.2        20.0        1.3           65   sj
# 484         7.385714        33.9        21.7        8.9           33   sj
#
#      month  PERSIANN_precip_mm_no_nans  NCEP_avg_temp_c  \
# 182      1                     43.9700              NaN
# 234      1                     62.6300              NaN
# 477      1                     50.9925              NaN
# 483      2                      0.0000        24.907143
# 484      2                      0.0000        24.957143
#
#      NCEP_avg_temp_c_no_nans  NCEP_diur_temp_rng_c  \
# 182                27.019643                   NaN
# 234                27.230357                   NaN
# 477                24.473214                   NaN
# 483                24.907143           -270.950000
# 484                24.957143           -270.564286
#
#      NCEP_diur_temp_rng_c_no_nans  NCEP_max_air_temp_c  \
# 182                   -263.675000                  NaN
# 234                   -263.567857                  NaN
# 477                   -270.910714                  NaN
# 483                   -270.950000                27.05
# 484                   -270.564286                26.95
#
#      NCEP_max_air_temp_c_no_nans  NCEP_min_air_temp_c  \
# 182                       33.900                  NaN
# 234                       34.925                  NaN
# 477                       26.700                  NaN
# 483                       27.050                22.15
# 484                       26.950                23.15
#
#      NCEP_min_air_temp_c_no_nans  NCEP_air_temp_c  NCEP_air_temp_c_no_nans  \
# 182                        20.90              NaN                25.777500
# 234                        20.60              NaN                25.735714
# 477                        22.55              NaN                24.290714
# 483                        22.15        24.648571                24.648571
# 484                        23.15        24.748571                24.748571
#
#      NCEP_dew_point_temp_c  NCEP_dew_point_temp_c_no_nans  avg_temp_c_no_nans  \
# 182                    NaN                      22.445000           28.447917
# 234                    NaN                      23.587857           28.658333
# 477                    NaN                      20.516071           25.196429
# 483              21.500000                      21.500000           26.028571
# 484              20.478571                      20.478571           25.757143
#
#      diur_temp_rng_c_no_nans  max_temp_c_no_nans  min_temp_c_no_nans  \
# 182                10.522917              34.625              22.400
# 234                10.683333              34.500              22.525
# 477                 6.925000              30.300              20.575
# 483                 6.571429              32.200              20.000
# 484                 7.385714              33.900              21.700
#
#      precip_mm_no_nans
# 182              56.35
# 234             125.25
# 477              25.25
# 483               1.30
# 484               8.90
